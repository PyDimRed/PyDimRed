# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import sys
import pandas as pd
sys.path.append('../dimred')
sys.path.append('../utils/')
import util

# %%
hello, colorize = util.make_hello(2000)

# %%
plt.figure(figsize=(12,8))
plt.scatter(hello[:, 0], hello[:, 1], **colorize)

# %%
hello_3d = np.linspace(1,100,num=2000) + np.random.rand(2000)
hello = pd.DataFrame(hello)
hello[2] = hello_3d
hello_3d = hello.as_matrix()

# %%
from mpl_toolkits import mplot3d
plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.scatter3D(hello_3d[:, 2], hello_3d[:,0], hello_3d[:, 1],
             **colorize);

# %% [markdown]
# # PCA

# %%
from pca import PCA

# %%
pca = PCA(2)

# %%
pca.fit(hello_3d)

# %%
X_new = pca.transform(hello_3d)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Random Projection

# %%
from random_projection import RandomProjection

# %%
random_proj = RandomProjection(n_component=2)

# %%
random_proj.fit(hello_3d)

# %%
X_new = random_proj.transform(hello_3d)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Isomap

# %%
from isomap import IsoMap

# %%
isomap = IsoMap(n_component=2, n_neighbour=30)

# %%
isomap.fit(hello_3d)

# %%
X_new = isomap.transform(hello_3d)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Laplacian method

# %%
from laplacian import Laplacian

# %%
laplacian = Laplacian(n_neighbours= 10, n_component=2)

# %%
laplacian.fit(hello_3d)

# %%
X_new = laplacian.transform()

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %%
hello, colorize = util.make_hello(2000)
hello_curve =util.make_hello_s_curve(hello)

# %%
from mpl_toolkits import mplot3d
plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.scatter3D(hello_curve[:, 0], hello_curve[:, 1], hello_curve[:, 2],
             **colorize);

# %% [markdown]
# # PCA

# %%
from pca import PCA

# %%
pca = PCA(2)

# %%
pca.fit(hello_curve)

# %%
X_new = pca.transform(hello_curve)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Random Projection

# %%
from random_projection import RandomProjection

# %%
random_proj = RandomProjection(n_component=2)

# %%
random_proj.fit(hello_curve)

# %%
X_new = random_proj.transform(hello_curve)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Isomap

# %%
from isomap import IsoMap

# %%
isomap = IsoMap(n_component=2, n_neighbour=70)

# %%
isomap.fit(hello_curve)

# %%
X_new = isomap.transform(hello_curve)

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %% [markdown]
# # Laplacian method

# %%
from laplacian import Laplacian

# %%
laplacian = Laplacian(n_neighbours= 20, n_component=2)

# %%
laplacian.fit(hello_curve)

# %%
X_new = laplacian.transform()

# %%
plt.figure(figsize=(12,8))
ax = plt.axes()
ax.scatter(X_new[:,0],X_new[:,1], **colorize);

# %%
S, color= util.make_S(2000)

# %%
fig = plt.figure(figsize=(50, 30))
ax = fig.add_subplot(251, projection='3d', )
ax.scatter(S[:, 0], S[:, 1], S[:, 2], c=color, cmap=plt.cm.Spectral)
ax.view_init(4, -72)

# %% [markdown]
# # PCA

# %%
from pca import PCA

# %%
pca = PCA(2)

# %%
pca.fit(S)

# %%
X_new = pca.transform(S)

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_new[:, 0], X_new[:, 1], c=color, cmap=plt.cm.Spectral)

# %% [markdown]
# # Random Projection

# %%
from random_projection import RandomProjection

# %%
random_proj = RandomProjection(n_component=2)

# %%
random_proj.fit(S)

# %%
X_new = random_proj.transform(S)

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_new[:, 0], X_new[:, 1], c=color, cmap=plt.cm.Spectral)

# %% [markdown]
# # Isomap

# %%
from isomap import IsoMap

# %%
isomap = IsoMap(n_component=2, n_neighbour=50)

# %%
isomap.fit(S)

# %%
X_new = isomap.transform(S)

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_new[:, 0], X_new[:, 1], c=color, cmap=plt.cm.Spectral)

# %% [markdown]
# # Laplacian method

# %%
from laplacian import Laplacian

# %%
laplacian = Laplacian(n_neighbours= 50, n_component=2)

# %%
laplacian.fit(S)

# %%
X_new = laplacian.transform()

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_new[:, 0], X_new[:, 1], c=color, cmap=plt.cm.Spectral)
